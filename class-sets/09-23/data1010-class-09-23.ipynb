# %% [markdown]
# # DATA 1010
#
# ### 23 September 2020: Machine Arithmetic and Condition Number
# ### Classtime problem set

# %%
using Plots

# %% [markdown]
# ## Problem 1
#
# (a) What's the main drawback of directly the using binary number system to represent integers in the machine?
#
# (b) Suppose $n \geq 1$ is an integer. Why is it clear that we cannot have an equal number of positives and negatives in any reasonable integer number system in which all of the length-n binary strings represent distinct integers?
#
# (c) Make a plot with bitstring binary values along the $x$-axis and corresponding *signed* integer values along the $y$-axis.
#
# (d) Find the length-8 bitstring representing $-1$ in Julia.
#
# (e) What do 125 and 5 sum to, in signed 8-bit integer arithmetic?

# %% [markdown]
# ## Problem 2
#
# (a) What's the problem with representing real-number values using multiples of some fixed constant $\epsilon>0$?

# %%
default(ratio = :auto, size = (700, 100), legend = false)
sticks(-2^4 : 1/2^3 : 2^4, x -> 0.2, ylims =(-1, 1))

# %% [markdown]
# (b) Come up with a good way to mitigate this problem.

# %% [markdown]
# ## Problem 3
#
# In the Float64 system, we can represent any numbers between $2^{-1022}$ and $2^{1024}$ without having to round it off any more than $1/2^{53}$ times its value.
#
#
# Why can we say $1/2^{53}$ in this statement even though the gap sizes are $1/2^{52}$ between 1 and 2?

# %% [markdown]
# ## Problem 4
#
# What is the condition number of the function $a\mapsto a - 1$?

# %% [markdown]
# ## Problem 5
#
# As a lead in to that discussion, I want to first ask: what is the difference between
# $f(x) = \sqrt{1 + x} - 1$
# and
# ```julia
# f(x) = √(1 + x) - 1
# ```
# ?
